# %%
import subprocess
def get_response(input_text: str, agent_path:str ):
    # 啟動 exe
    proc = subprocess.Popen(
        [agent_path],
        stdin=subprocess.PIPE,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True
    )

    # 將 input_text 寫入 stdin，並讀取 stdout/stderr
    stdout, stderr = proc.communicate(input_text)

    return stdout, stderr

def get_move(response_text):
    return response_text.split("\n")[-2]

def get_FEN(response_text):
    return response_text.split("\n")[-1]

def get_board(response_text):
    board = ''
    for s in  response_text.split("\n")[-14:]:
        board += s+"\n"
    return board

# %%
board = "A6P/8/8/8 b"[:-1]

any(c.islower() for c in board) ,any(c.isupper() for c in board)
# Out:
# (False, True)

# %%
board = "A6p/8/8/8 b"

Red_Win = False
Black_Win = False

move = 0
while not ( Red_Win or Black_Win):
    res = (get_response(board,"./wakasagi")[0])
    board = get_FEN(res)
    b = board.split(" ")[0]
    Black_Win = not any(not c.islower() for c in b)
    Red_Win = not any(not c.isupper() for c in b)
    move += 1
    print(f"|{b}|")
    print(Red_Win, Black_Win)
    print(any([not c.islower() for c in b]))
    print(any([not c.isupper() for c in b]))

print('board:', board)
print("winner:")
if Red_Win:
    print("\t Red")
else:
    print("\t Black")

print('move:', move)
# Out:
# |1A5p/8/8/8|
# False False
# True
# True
# |1A6/7p/8/8|
# False False
# True
# True
# |8/1A5p/8/8|
# False False
# True
# True
# |8/1A6/7p/8|
# False False
# True
# True
# |8/8/1A5p/8|
# False False
# True
# True
# |8/7p/1A6/8|
# False False
# True
# True
# |8/7p/2A5/8|
# False False
# True
# True
# |8/8/2A4p/8|
# False False
# True
# True
# |8/8/7p/2A5|
# False False
# True
# True
# |8/7p/8/2A5|
# False False
# True
# True
# |8/7p/8/3A4|
# False False
# True
# True
# |7p/8/8/3A4|
# False False
# True
# True
# |7p/8/8/4A3|
# False False
# True
# True
# |8/7p/8/4A3|
# False False
# True
# True
# |8/7p/8/5A2|
# False False
# True
# True
# |7p/8/8/5A2|
# False False
# True
# True
# |7p/8/8/6A1|
# False False
# True
# True
# |6p1/8/8/6A1|
# False False
# True
# True
# |6p1/8/6A1/8|
# False False
# True
# True
# |5p2/8/6A1/8|
# False False
# True
# True
# |5p2/6A1/8/8|
# False False
# True
# True
# |4p3/6A1/8/8|
# False False
# True
# True
# |4p3/5A2/8/8|
# False False
# True
# True
# |3p4/5A2/8/8|
# False False
# True
# True
# |3p4/4A3/8/8|
# False False
# True
# True
# |2p5/4A3/8/8|
# False False
# True
# True
# |2p5/3A4/8/8|
# False False
# True
# True
# |1p6/3A4/8/8|
# False False
# True
# True
# |1p6/2A5/8/8|
# False False
# True
# True
# |p7/2A5/8/8|
# False False
# True
# True
# |p7/1A6/8/8|
# False False
# True
# True
# |1p6/1A6/8/8|
# False False
# True
# True
# |1A6/8/8/8|
# False False
# True
# True
# ||
# True True
# False
# False
# board:
# winner:
# 	 Red
# move: 34

# %%
b = '8/A7/8/8 '
any(c.islower() for c in b),any(c.isupper() for c in b)
# Out:
# (False, True)

# %%
any(c.is
winner:
     Redlower() for c in board[:-1])
# Out:
# True
